# %%
# !wget https://github.com/GwenONERA/CyberBullying/raw/refs/heads/main/Data/CyberBullyingAdo.parquet
# Out:
# --2026-03-04 15:45:48--  https://github.com/GwenONERA/CyberBullying/raw/refs/heads/main/Data/CyberBullyingAdo.parquet
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/GwenONERA/CyberBullying/refs/heads/main/Data/CyberBullyingAdo.parquet [following]
# --2026-03-04 15:45:48--  https://raw.githubusercontent.com/GwenONERA/CyberBullying/refs/heads/main/Data/CyberBullyingAdo.parquet
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 262474 (256K) [application/octet-stream]
# Saving to: ‘CyberBullyingAdo.parquet’
#
# CyberBullyingAdo.pa 100%[===================>] 256.32K  --.-KB/s    in 0.03s
#
# 2026-03-04 15:45:48 (9.37 MB/s) - ‘CyberBullyingAdo.parquet’ saved [262474/262474]

# %%
#!/usr/bin/env python3
"""
SMS / argot toxique  →  français standard — Extracteur de paires via Gemini (Colab).

Pipeline :
  1. Charge les textes de CyberBullyingAdo.parquet à partir de la ligne START_ROW
  2. Filtre les entrées sans lettre latine ET les textes triviaux
  3. Envoie chaque texte à Gemini avec un prompt-template strict
  4. Parse les réponses JSON, stocke les paires {source, target} + contexte
  5. Détecte la polysémie, produit un CSV et un JSON déduplicé
  6. Append aux fichiers existants si reprise d'exécution
"""

import json
import os
import re
import time
import pandas as pd
from google.colab import ai

# ══════════════════════════════════════════════════════════════════════
# 0.  CONFIGURATION — MODIFIER ICI POUR REPRENDRE
# ══════════════════════════════════════════════════════════════════════
PARQUET_PATH = "./CyberBullyingAdo.parquet"

START_ROW    = 100          # ← première ligne à traiter (0-indexed)
N_TEXTS      = 1000          # nombre de lignes à traiter à partir de START_ROW
END_ROW      = START_ROW + N_TEXTS  # → lignes [100, 200)

OUTPUT_CSV   = "sms_to_french_pairs.csv"
OUTPUT_JSON  = "sms_to_french_pairs.json"
API_DELAY    = 0.5          # secondes entre chaque appel (anti rate-limit)

# Mots triviaux à exclure (le texte entier, après strip+lower, ==)
TRIVIAL_TEXTS = {"oui", "non", "salut", "bonjour"}

# ══════════════════════════════════════════════════════════════════════
# 1.  CHARGEMENT & FILTRAGE
# ══════════════════════════════════════════════════════════════════════
df = pd.read_parquet(PARQUET_PATH)
print(f"[info] Dataset complet : {len(df)} lignes")

# Tranche [START_ROW, END_ROW)
if END_ROW > len(df):
    END_ROW = len(df)
    print(f"[info] END_ROW ajusté à {END_ROW} (fin du dataset)")

df_subset = df.iloc[START_ROW:END_ROW].copy()
print(f"[info] Tranche sélectionnée : lignes {START_ROW} → {END_ROW-1}  "
      f"({len(df_subset)} lignes)")

# ── Précaution 1a : garder uniquement les textes contenant ≥ 1 lettre latine
_LATIN_RE = re.compile(
    r'[a-zA-ZàâäéèêëïîôöùûüÿçœæÀÂÄÉÈÊËÏÎÔÖÙÛÜŸÇŒÆ]'
)

def has_latin(text: str) -> bool:
    return isinstance(text, str) and bool(_LATIN_RE.search(text))

mask_latin = df_subset['TEXT'].apply(has_latin)
n_no_latin = (~mask_latin).sum()

# ── Précaution 1b : exclure les textes triviaux (mot unique sans intérêt)
def is_trivial(text: str) -> bool:
    if not isinstance(text, str):
        return True
    cleaned = text.strip().lower()
    # Supprime ponctuation terminale pour attraper "Salut." / "Oui !"
    cleaned = re.sub(r'[.!?,;:\s]+$', '', cleaned)
    cleaned = re.sub(r'^[.!?,;:\s]+', '', cleaned)
    return cleaned in TRIVIAL_TEXTS

mask_trivial = df_subset['TEXT'].apply(is_trivial)
n_trivial = mask_trivial.sum()

# Combinaison des deux filtres
df_filtered = df_subset[mask_latin & ~mask_trivial].copy()
n_removed = len(df_subset) - len(df_filtered)

print(f"[info] Filtrés → sans lettre latine : {n_no_latin}, "
      f"triviaux ({', '.join(sorted(TRIVIAL_TEXTS))}) : {n_trivial}")
print(f"[info] Après filtrage : {len(df_filtered)} textes retenus "
      f"({n_removed} écarté{'s' if n_removed > 1 else ''})\n")

# ══════════════════════════════════════════════════════════════════════
# 2.  PROMPT TEMPLATE
# ══════════════════════════════════════════════════════════════════════
KNOWN_SUSPECTS = (
    "tkt, ptn, ntm, ftg, vrm, vrmt, tjrs, srx, dsl, jte, mtn, ouf, "
    "tqt, jsp, msg, bjr, wlh, fdp, tdc, jtm, nn, bh, xd, lvdm, cc, "
    "tktt, tktp, tsais, jss, mwa, lea, çca, psq, léa, 5eu, tai, sonb, "
    "cbvn, tfk, ftp, ltn, fgtg, irl, rsa, vpn, vmt, vbn, ojn, tjr, "
    "mvs, csc, uqi, oeeee, dégouteeee, bisoussssssssssssssssssssssssssss, "
    "mdmrmrr, bk, dz, pg, sl, ls, da, ds, cq"
)

PROMPT_TEMPLATE = """\
Tu es un expert en linguistique française, spécialisé dans l'argot des \
jeunes de 12-20 ans et dans le langage toxique du cyber-harcèlement en \
ligne (réseaux sociaux, SMS, messageries).

## TÂCHE
Analyse le texte ci-dessous. Identifie **chaque** mot ou groupe de mots \
correspondant à l'un de ces cas :
1. Mal orthographié / écriture SMS / abréviation \
   (ex : "rep" → "réponds", "vrm" → "vraiment", "bcp" → "beaucoup")
2. Insulte abrégée ou codée \
   (ex : "fdp" → "fils de pute", "ntm" → "nique ta mère", "tg" → "ta gueule")
3. Verlan ou argot absent d'un dictionnaire français standard \
   (ex : "teubé" → "bête", "zer" → "laser/bizarre selon contexte")
4. Chiffre(s) substitué(s) à des lettres \
   (ex : "2m1" → "demain", "3a0" → "zéro")
5. Mot tronqué \
   (ex : "tjrs" → "toujours", "mtn" → "maintenant", "srx" → "sérieux")
6. Émoticône textuelle : traduis par sa signification émotionnelle \
   (ex : "xd" → "rire", ":)" → "sourire", "^^" → "content")
7. Onomatopée ou mot allongé : donne la forme standard \
   (ex : "bisoussss" → "bisous", "trooooop" → "trop")

## CHAÎNES SUSPECTES CONNUES (à rechercher en priorité)
{suspects}

## RÈGLES STRICTES
- Retourne **UNIQUEMENT** un tableau JSON valide. Aucun texte, aucun \
  commentaire, aucun markdown autour.
- Chaque élément : {{"source": "<mot exact du texte>", "target": "<forme standard>"}}.
- **NE traduis PAS** les mots existant dans un dictionnaire français \
  standard, même familiers : "ouais", "ok", "mec", "meuf", "truc", \
  "genre", "gars", "bof", "sympa", "mdr", "lol", "nul", "chiant", \
  "pote" sont valides — ne les corrige pas.
- **NE corrige PAS** la grammaire ni la syntaxe (accords, conjugaisons, \
  ponctuation). Corrige uniquement le **vocabulaire** SMS/abrégé/toxique.
- **Respecte le contexte** pour les mots polysémiques. \
  "sa" peut être "ça" ou le possessif "sa" : choisis selon la phrase.
- Si le texte ne contient AUCUN mot à corriger, retourne : []

## EXEMPLES IN-CONTEXT

Input: "t ou ptn tu rep jamais fdp"
Output: [{{"source": "t", "target": "t'es"}}, {{"source": "ptn", "target": "putain"}}, {{"source": "rep", "target": "réponds"}}, {{"source": "fdp", "target": "fils de pute"}}]

Input: "wlh tkt jvais le niquer srx"
Output: [{{"source": "wlh", "target": "wallah"}}, {{"source": "tkt", "target": "t'inquiète"}}, {{"source": "jvais", "target": "je vais"}}, {{"source": "srx", "target": "sérieux"}}]

Input: "non, pas trop"
Output: []

## TEXTE À ANALYSER
\"\"\"{text}\"\"\"

## SORTIE JSON :"""

# ══════════════════════════════════════════════════════════════════════
# 3.  CHARGEMENT DES RÉSULTATS EXISTANTS (REPRISE)
# ══════════════════════════════════════════════════════════════════════
existing_pairs: list[dict] = []
if os.path.exists(OUTPUT_CSV):
    try:
        existing_df = pd.read_csv(OUTPUT_CSV)
        existing_pairs = existing_df.to_dict('records')
        print(f"[info] Fichier existant '{OUTPUT_CSV}' chargé : "
              f"{len(existing_pairs)} paires précédentes\n")
    except Exception as exc:
        print(f"[warn] Impossible de charger '{OUTPUT_CSV}' : {exc}\n")

# ══════════════════════════════════════════════════════════════════════
# 4.  BOUCLE PRINCIPALE : INFÉRENCE + PARSING
# ══════════════════════════════════════════════════════════════════════
new_pairs: list[dict]    = []
failed_indices: list[int] = []
empty_count = 0

print("═" * 72)
print(f"  Traitement de {len(df_filtered)} textes via Gemini (Colab AI)")
print(f"  Plage : lignes {START_ROW} → {END_ROW - 1}")
print("═" * 72 + "\n")

for i, (row_idx, row) in enumerate(df_filtered.iterrows()):
    text = str(row['TEXT']).strip()
    if not text:
        continue

    prompt = PROMPT_TEMPLATE.format(
        text=text.replace('"', '\\"'),
        suspects=KNOWN_SUSPECTS,
    )

    try:
        response = ai.generate_text(prompt)
        raw = response.strip()

        json_match = re.search(r'\[.*?\]', raw, re.DOTALL)

        if json_match:
            pairs = json.loads(json_match.group(0))

            if not isinstance(pairs, list):
                raise ValueError("La réponse JSON n'est pas une liste")

            n_valid = 0
            for pair in pairs:
                if (isinstance(pair, dict)
                        and 'source' in pair
                        and 'target' in pair
                        and pair['source'].strip()
                        and pair['target'].strip()):
                    new_pairs.append({
                        'source':     pair['source'].strip().lower(),
                        'target':     pair['target'].strip().lower(),
                        'context':    text,
                        'text_index': int(row_idx),
                    })
                    n_valid += 1

            if n_valid:
                print(f"  [{i+1:3d}/{len(df_filtered)}] ✓ {n_valid:2d} paire(s)  "
                      f"│ {text[:60]}{'…' if len(text)>60 else ''}")
            else:
                empty_count += 1
                print(f"  [{i+1:3d}/{len(df_filtered)}] · aucun argot  "
                      f"│ {text[:60]}{'…' if len(text)>60 else ''}")

        elif '[]' in raw:
            empty_count += 1
            print(f"  [{i+1:3d}/{len(df_filtered)}] · aucun argot  "
                  f"│ {text[:60]}{'…' if len(text)>60 else ''}")
        else:
            print(f"  [{i+1:3d}/{len(df_filtered)}] ⚠ pas de JSON  "
                  f"│ réponse brute : {raw[:80]}")
            failed_indices.append(row_idx)

    except json.JSONDecodeError as exc:
        print(f"  [{i+1:3d}/{len(df_filtered)}] ✗ JSON invalide : {exc}")
        failed_indices.append(row_idx)
    except Exception as exc:
        print(f"  [{i+1:3d}/{len(df_filtered)}] ✗ Erreur API : {exc}")
        failed_indices.append(row_idx)

    time.sleep(API_DELAY)

# ══════════════════════════════════════════════════════════════════════
# 5.  FUSION AVEC LES RÉSULTATS PRÉCÉDENTS
# ══════════════════════════════════════════════════════════════════════
all_pairs = existing_pairs + new_pairs

print(f"\n{'═' * 72}")
print("  RÉSULTATS")
print("═" * 72)

pairs_df = pd.DataFrame(all_pairs)
n_pairs   = len(pairs_df)
n_new     = len(new_pairs)
n_prev    = len(existing_pairs)
n_unique  = pairs_df['source'].nunique() if n_pairs else 0

print(f"\n  Nouvelles paires (cette exécution)  : {n_new}")
print(f"  Paires précédentes (reprises)       : {n_prev}")
print(f"  Total cumulé                        : {n_pairs}")
print(f"  Termes source uniques (cumulé)      : {n_unique}")
print(f"  Textes sans argot (cette exécution) : {empty_count}")
print(f"  Échecs (parse / API, cette exec.)   : {len(failed_indices)}")

if n_pairs == 0:
    print("\n  ⚠ Aucune paire n'a été extraite — vérifier les appels API.")
    raise SystemExit

# ── Précaution 2 : Détection de polysémie ────────────────────────────
polysemy = (
    pairs_df
    .groupby('source')['target']
    .apply(lambda s: sorted(set(s)))
    .reset_index()
)
polysemy['n_targets'] = polysemy['target'].apply(len)
multi = polysemy[polysemy['n_targets'] > 1].sort_values(
    'n_targets', ascending=False
)

if len(multi):
    print(f"\n  ⚠ Termes polysémiques ({len(multi)} source(s) → cibles multiples) :")
    for _, r in multi.iterrows():
        print(f"    '{r['source']}' → {r['target']}")

# ── Table de fréquences ──────────────────────────────────────────────
freq = (
    pairs_df
    .groupby(['source', 'target'])
    .agg(count=('source', 'size'))
    .reset_index()
    .sort_values('count', ascending=False)
    .reset_index(drop=True)
)

print(f"\n  Top-30 des mappings les plus fréquents (cumulé) :\n")
with pd.option_context('display.max_colwidth', 40, 'display.width', 120):
    print(freq.head(30).to_string(index=False))

# ══════════════════════════════════════════════════════════════════════
# 6.  SAUVEGARDE (ÉCRASEMENT AVEC DONNÉES CUMULÉES)
# ══════════════════════════════════════════════════════════════════════
pairs_df.to_csv(OUTPUT_CSV, index=False, encoding='utf-8-sig')
print(f"\n[saved] {OUTPUT_CSV}  ({n_pairs} lignes cumulées)")

# ── JSON : dictionnaire dédupliqué avec exemples de contexte ──────────
dict_entries = []
for src in pairs_df['source'].unique():
    sub = pairs_df[pairs_df['source'] == src]
    targets_agg = (
        sub.groupby('target')
        .agg(
            frequency=('target', 'size'),
            example_contexts=('context', lambda x: list(x.unique())[:3]),
        )
        .reset_index()
    )
    for _, t_row in targets_agg.iterrows():
        dict_entries.append({
            'source':           src,
            'target':           t_row['target'],
            'frequency':        int(t_row['frequency']),
            'example_contexts': t_row['example_contexts'],
        })

with open(OUTPUT_JSON, 'w', encoding='utf-8') as f:
    json.dump(dict_entries, f, ensure_ascii=False, indent=2)
print(f"[saved] {OUTPUT_JSON}  ({len(dict_entries)} entrées)")

# ══════════════════════════════════════════════════════════════════════
# 7.  RÉSUMÉ & INDICATION POUR LA PROCHAINE EXÉCUTION
# ══════════════════════════════════════════════════════════════════════
next_start = END_ROW
print(f"\n{'═' * 72}")
print("  RÉSUMÉ")
print("═" * 72)
print(f"  • Plage traitée      : lignes {START_ROW} → {END_ROW - 1}")
print(f"  • {len(df_filtered)} textes traités (après filtrage)")
print(f"  • {n_new} nouvelles paires extraites")
print(f"  • {n_pairs} paires cumulées au total")
print(f"  • {n_unique} termes source uniques")
print(f"  • {len(multi)} termes polysémiques détectés")
print(f"  • Fichiers : {OUTPUT_CSV}, {OUTPUT_JSON}")
print(f"\n  ➜ Pour la prochaine exécution, modifier :")
print(f"      START_ROW = {next_start}")
print(f"\n✓  Pipeline terminé.\n")
# Out:
# [info] Dataset complet : 5608 lignes
# [info] Tranche sélectionnée : lignes 100 → 1099  (1000 lignes)
# [info] Filtrés → sans lettre latine : 9, triviaux (bonjour, non, oui, salut) : 7
# [info] Après filtrage : 984 textes retenus (16 écartés)
#
# ════════════════════════════════════════════════════════════════════════
#   Traitement de 984 textes via Gemini (Colab AI)
#   Plage : lignes 100 → 1099
# ════════════════════════════════════════════════════════════════════════
#
#   [  1/984] · aucun argot  │ Oh calmez-vous on est quand même pote tout de même
#   [  2/984] · aucun argot  │ je le pensais mais bon
#   [  3/984] ✓  2 paire(s)  │ je suis pas potes avec des aguicheuse pareil ! je voudrait p…
#   [  4/984] · aucun argot  │ tais-toi
#   [  5/984] · aucun argot  │ apprend a lire avant de me parler
#   [  6/984] · aucun argot  │ attentionnellement*
#   [  7/984] ✓  1 paire(s)  │ je pique les mecs moi apparement
#   [  8/984] · aucun argot  │ j'ai pas besoin de savoir lire
#   [  9/984] · aucun argot  │ ouais
#   [ 10/984] ✓  2 paire(s)  │ ohhh ca part bien
#   [ 11/984] ✓  2 paire(s)  │ parceque t une pute qui les chauffe et qui les paie
#   [ 12/984] ✓  1 paire(s)  │ t'es une pute qui n'arrive pas a trouver de mec
#   [ 13/984] · aucun argot  │ c'est ton père qui les paie
#   [ 14/984] ✓  1 paire(s)  │ et apres tu leur donne des MST
#   [ 15/984] · aucun argot  │ si tu veux être une pute personne t'oblige a lire
#   [ 16/984] · aucun argot  │ personne oblige ta soeur à savoir lire non plus
#   [ 17/984] · aucun argot  │ le mien il a de l argent au moins
#   [ 18/984] ✓  1 paire(s)  │ et il apie
#   [ 19/984] · aucun argot  │ paie
#   [ 20/984] ✓  2 paire(s)  │ il m envoie pas au bar a pute comme toi
#   [ 21/984] ✓  1 paire(s)  │ tout sa parce que t'es jalouse de leurs amour connasse
#   [ 22/984] · aucun argot  │ il a pas besoin d'aller au bar
#   [ 23/984] ✓  1 paire(s)  │ il leur paie des apparts privés
#   [ 24/984] · aucun argot  │ apprend a écrire connasse
#   [ 25/984] · aucun argot  │ après c'est pas difficile savoir où t'es pendant la nuit
#   [ 26/984] ✓  1 paire(s)  │ t conne
#   [ 27/984] · aucun argot  │ pute
#   [ 28/984] · aucun argot  │ salope
#   [ 29/984] · aucun argot  │ enculé
#   [ 30/984] ✓  2 paire(s)  │ Adri calme-toi ça sert à rien de sénerver
#   [ 31/984] · aucun argot  │ alors plus rien à dire Silvia?
#   [ 32/984] ✓  1 paire(s)  │ écoute si tu es frustré pcq tu en as une mini c'est pas de m…
#   [ 33/984] ✓  1 paire(s)  │ T'as enfin fermé ta gueule?
#   [ 34/984] ✓  1 paire(s)  │ te mele pas de ca herbert
#   [ 35/984] · aucun argot  │ même une aveugle cul de jatte serait pas excitée par toi
#   [ 36/984] ✓  2 paire(s)  │ On se calme arreter de l'attaquer tout le temps a la fin
#   [ 37/984] ✓  1 paire(s)  │ Tkt Soan ils me font pitié
#   [ 38/984] ✓  1 paire(s)  │ tu prend tout ton temps pour embrasser des mecs en couple c'…
#   [ 39/984] · aucun argot  │ tu as trouver une nouvelle cible ?
#   [ 40/984] · aucun argot  │ tu veux que j'essaie le tien?
#   [ 41/984] ✓  1 paire(s)  │ viens la voir et verrai quel fera plus mal que ce que tu cro…
#   [ 42/984] ✓  1 paire(s)  │ t encore pucelle et tu parle avec moi
#   [ 43/984] ✓  2 paire(s)  │ moi jai enculé ta darronne la salope
#   [ 44/984] ✓  1 paire(s)  │ cette pute la marrave
#   [ 45/984] · aucun argot  │ Parle bien fils
#   [ 46/984] ✓  1 paire(s)  │ herbert arrete
#   [ 47/984] · aucun argot  │ t'es venu au nom de dieu Herbert?
#   [ 48/984] · aucun argot  │ alors on ferme sa gueule
#   [ 49/984] ✓  1 paire(s)  │ bien ouej adri
#   [ 50/984] · aucun argot  │ ne te mele pas plus
#   [ 51/984] · aucun argot  │ tu veux quoi herbert qu'elle t'embrasse aussi ?
#   [ 52/984] ✓  4 paire(s)  │ pédale des qu on est triste on va pleuré chez papa pendant q…
#   [ 53/984] · aucun argot  │ tu la kiffe cette pétasse ?
#   [ 54/984] ✓  1 paire(s)  │ allé un nouveau client pour toi Silvia
#   [ 55/984] · aucun argot  │ Les gars vous tourné pas contre moi
#   [ 56/984] · aucun argot  │ félicitations
#   [ 57/984] ✓  1 paire(s)  │ c'est toi qui se mele
#   [ 58/984] ✓  1 paire(s)  │ Je veux juste que ça sarange
#   [ 59/984] ✓  2 paire(s)  │ tu es de son côté alors qu'elle traine son cul sale partout …
#   [ 60/984] ✓  4 paire(s)  │ c vrai herbert il est nien il a pas pécho le mec de sophie l…
#   [ 61/984] · aucun argot  │ tu dois kiffer
#   [ 62/984] · aucun argot  │ bah c'est pas toi qui va y réussir Einstein
#   [ 63/984] ✓  3 paire(s)  │ ban t ou sylvia on t entend plus
#   [ 64/984] ✓  1 paire(s)  │ tkt pas Silvia ce sont que des cons
#   [ 65/984] ✓  1 paire(s)  │ sylvia ouuouuu?
#   [ 66/984] · aucun argot  │ pas plus que toi Soan
#   [ 67/984] ✓  1 paire(s)  │ laiisser
#   [ 68/984] · aucun argot  │ Alors Silvia?
#   [ 69/984] ✓  1 paire(s)  │ déso j'avais plus de connexion
#   [ 70/984] · aucun argot  │ merde
#   [ 71/984] · aucun argot  │ donc on en était où?
#   [ 72/984] ✓  1 paire(s)  │ deja on est pas con soan
#   [ 73/984] · aucun argot  │ ah oui
#   [ 74/984] · aucun argot  │ C'est bon au pire laissez la et on passe à autre chose, vous…
#   [ 75/984] · aucun argot  │ Adrien
#   [ 76/984] · aucun argot  │ c'est ça ton excuse de merde?
#   [ 77/984] ✓  3 paire(s)  │ ces ton pere qui la pomper comme toi avec les mecs!!!!!!!!!!…
#   [ 78/984] ✓  1 paire(s)  │ Je vais demander à ton père de me payer un vrai phone
#   [ 79/984] ✓  1 paire(s)  │ mon père est mort fdp
#   [ 80/984] ✓  2 paire(s)  │ mais vazi sens toi mieux mtnt
#   [ 81/984] ✓  1 paire(s)  │ c'est parce qu'il a eu une vrai leçon, lui aussi il piquer l…
#   [ 82/984] ✓  2 paire(s)  │ il pourras pas t acheter de tel
#   [ 83/984] · aucun argot  │ le tien oui
#   [ 84/984] ✓  1 paire(s)  │ respecter sa famille puatin
#   [ 85/984] ✓  1 paire(s)  │ sa fammille de pute
#   [ 86/984] ✓  1 paire(s)  │ cest pas respectable
#   [ 87/984] · aucun argot  │ techniquement mon père était comptable
#   [ 88/984] · aucun argot  │ mais si tu veux
#   [ 89/984] ✓  3 paire(s)  │ si il est mort c est de tas faute parce que t une grosse put…
#   [ 90/984] · aucun argot  │ il s est suicider
#   [ 91/984] ✓  1 paire(s)  │ comptable de pute entre ta mere et toi
#   [ 92/984] · aucun argot  │ il les collectionnent
#   [ 93/984] · aucun argot  │ salope
#   [ 94/984] · aucun argot  │ a propos de pute
#   [ 95/984] ✓  2 paire(s)  │ Et ta soeur elle veut meme plus te voir Adrien alors tait to…
#   [ 96/984] · aucun argot  │ demande à ta mère comment elle arrive à te faire manger
#   [ 97/984] · aucun argot  │ Silvia comprend qu'on est énervé je te conseille de quitter …
#   [ 98/984] · aucun argot  │ Mais oui...
#   [ 99/984] · aucun argot  │ on m'insulte et je dois faire l'autruche
#   [100/984] · aucun argot  │ t'as vu ça où?
#   [101/984] ✓  1 paire(s)  │ non reste je vais te demonte ta gueule qui suce des bites
#   [102/984] · aucun argot  │ vas-y grosse pute. tu te sens mal maintenant enfin
#   [103/984] · aucun argot  │ personne te la suce la tienne
#   [104/984] ✓  1 paire(s)  │ comme une autruche tu met ta tete dans des trou ?
#   [105/984] ✓  4 paire(s)  │ Ca commence a etre lourd la
#   [106/984] ✓  1 paire(s)  │ parce que elle est trop grosse pour rentrer dans ta boche
#   [107/984] · aucun argot  │ ton père plein de mst il met autre chose dans des trous
#   [108/984] ✓  2 paire(s)  │ met ta tete entre tes cuisses a la place de prendre les mecs…
984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002178) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [915/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002172) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [916/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002178) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [917/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002169) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [918/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002235) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [919/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002205) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [920/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002178) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [921/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002184) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [922/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002166) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [923/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002193) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [924/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002181) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [925/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002184) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [926/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002214) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [927/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002184) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [928/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002169) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [929/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002172) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [930/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002166) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [931/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002175) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [932/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002193) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [933/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002178) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [934/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002196) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [935/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002175) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [936/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002193) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [937/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002226) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [938/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002193) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [939/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002163) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [940/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002199) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [941/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002172) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [942/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002169) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [943/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002187) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [944/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002214) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [945/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.000219) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [946/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002217) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [947/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002184) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [948/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002193) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [949/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002187) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [950/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002196) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [951/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002202) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [952/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002193) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [953/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.000219) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [954/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002181) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [955/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002196) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [956/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002187) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [957/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002169) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [958/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002172) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [959/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002214) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [960/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002271) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [961/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002166) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [962/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002169) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [963/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002184) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [964/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002163) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [965/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002199) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [966/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002181) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [967/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002181) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [968/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002175) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [969/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002286) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [970/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002238) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [971/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002178) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [972/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002211) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [973/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002163) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [974/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002205) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [975/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002169) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [976/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002172) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [977/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002184) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [978/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002181) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [979/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002178) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [980/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002193) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [981/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002199) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [982/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002172) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [983/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002199) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#   [984/984] ✗ Erreur API : Error code: 429 - {'message': 'The estimated cost of this operation ($0.0002181) exceeds your available quota. Try again later.', 'type': 'invalid_request_error'}
#
# ════════════════════════════════════════════════════════════════════════
#   RÉSULTATS
# ════════════════════════════════════════════════════════════════════════
#
#   Nouvelles paires (cette exécution)  : 390
#   Paires précédentes (reprises)       : 0
#   Total cumulé                        : 390
#   Termes source uniques (cumulé)      : 241
#   Textes sans argot (cette exécution) : 171
#   Échecs (parse / API, cette exec.)   : 580
#
#   ⚠ Termes polysémiques (9 source(s) → cibles multiples) :
#     't' → ["t'es", 'te', 'tu']
#     'seum' → ['dégoût', 'rage', 'rancœur']
#     'bz' → ['baise', 'baisé']
#     'cest' → ["c'est", 'ces']
#     'meme' → ['même', 'mêmes']
#     'pécho' → ['draguer', 'séduire']
#     'oe' → ['ouais', 'oui']
#     'qu'es' → ["qu'est", "qu'est-ce"]
#     't'es' → ['tes', 'tu es']
#
#   Top-30 des mappings les plus fréquents (cumulé) :
#
#   source          target  count
#        a               à     23
#       tg       ta gueule     14
#        c           c'est      9
#        t            t'es      8
#      tkt      t'inquiète      7
#       sa              ça      7
#       ca              ça      7
#     meme            même      7
#       la              là      6
#     mere            mère      6
#   arrete          arrête      6
#    apres           après      4
#      jai            j'ai      4
#       vs            vous      4
#     pere            père      3
# parceque       parce que      3
#      t’a           tu as      3
#       cu             cul      3
#       ta           tu as      3
#        t              tu      3
#      frr           frère      3
#      ftg ferme ta gueule      2
#        j              je      2
#       bz           baisé      2
#      :')  rire larmoyant      2
#  leglise        l'église      2
#     deja            déjà      2
#     cest           c'est      2
#     ouej            joué      2
#    pécho         séduire      2
#
# [saved] sms_to_french_pairs.csv  (390 lignes cumulées)
# [saved] sms_to_french_pairs.json  (252 entrées)
#
# ════════════════════════════════════════════════════════════════════════
#   RÉSUMÉ
# ════════════════════════════════════════════════════════════════════════
#   • Plage traitée      : lignes 100 → 1099
#   • 984 textes traités (après filtrage)
#   • 390 nouvelles paires extraites
#   • 390 paires cumulées au total
#   • 241 termes source uniques
#   • 9 termes polysémiques détectés
#   • Fichiers : sms_to_french_pairs.csv, sms_to_french_pairs.json
#
#   ➜ Pour la prochaine exécution, modifier :
#       START_ROW = 1100
#
# ✓  Pipeline terminé.
